# %% [markdown]
# <a href="https://colab.research.google.com/github/inderpreetsingh01/PyMath/blob/main/Python4DA_Ch5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from pandas import Series, DataFrame

# %% [markdown]
# ## Series

# %%
series = pd.Series([1,2,3,4])

# %%
series.array
# Out:
# <NumpyExtensionArray>
# [np.int64(1), np.int64(2), np.int64(3), np.int64(4)]
# Length: 4, dtype: int64

# %%
series.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
series = pd.Series([1,2,3,4], index=['a', 'b', 'c', 'd'])
series
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
series[series>2]
# Out:
# c    3
# d    4
# dtype: int64

# %%
dic = series.to_dict()
dic
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
pd.Series(dic)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
series*2
# Out:
# a    2
# b    4
# c    6
# d    8
# dtype: int64

# %%
np.exp(series)
# Out:
# a     2.718282
# b     7.389056
# c    20.085537
# d    54.598150
# dtype: float64

# %%
series["a"]
# Out:
# np.int64(1)

# %%
series[["a", "b", "c"]]
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
"a" in series
# Out:
# True

# %%
"a" not in series
# Out:
# False

# %%
sdata = {"Ohio": 35000, "Texas": 71000, "Oregon": 16000, "Utah": 5000}
obj3 = pd.Series(sdata)

# %%
# giving index to dictionary will follow the provided index
states = ["California", "Ohio", "Oregon", "Texas"]
obj4 = pd.Series(sdata, index=states)

# %%
obj4
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
pd.isna(obj4)
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
pd.notna(obj4)
# Out:
# California    False
# Ohio           True
# Oregon         True
# Texas          True
# dtype: bool

# %%
# isna() as series instance method
obj4.isna()
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
obj4.name = 'state'

# %%
obj4.index.name = 'state_name'

# %%
obj4
# Out:
# state_name
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# Name: state, dtype: float64

# %%
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
obj4
# Out:
# state_name
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# Name: state, dtype: float64

# %%
# pandas aligns index by itself, similar to inner join in sql
obj3+obj4
# Out:
# California         NaN
# Ohio           70000.0
# Oregon         32000.0
# Texas         142000.0
# Utah               NaN
# dtype: float64

# %%
# index can be changed in place
obj4.index = ["a", "b", "c", "d"]

# %%
obj4
# Out:
# a        NaN
# b    35000.0
# c    16000.0
# d    71000.0
# Name: state, dtype: float64

# %% [markdown]
# ## DataFrame

# %%
data = {"state": ["Ohio", "Ohio", "Ohio", "Nevada", "Nevada", "Nevada"],
        "year": [2000, 2001, 2002, 2001, 2002, 2003],
        "pop": [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}
df = pd.DataFrame(data)

# %%
df
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
df.head()
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %%
df.tail(2)
# Out:
#     state  year  pop
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
# column not present in dic column is filled with NaN for that column
# order of columns will follow the order provided
frame2 = pd.DataFrame(data, columns=["year", "state", "pop", "debt"])

# %%
frame2
# Out:
#    year   state  pop debt
# 0  2000    Ohio  1.5  NaN
# 1  2001    Ohio  1.7  NaN
# 2  2002    Ohio  3.6  NaN
# 3  2001  Nevada  2.4  NaN
# 4  2002  Nevada  2.9  NaN
# 5  2003  Nevada  3.2  NaN

# %%
frame2['year']
# Out:
# 0    2000
# 1    2001
# 2    2002
# 3    2001
# 4    2002
# 5    2003
# Name: year, dtype: int64

# %%
# dont wont work in all the cases, if name has space then wont work but above one will work always
frame2.state
# Out:
# 0      Ohio
# 1      Ohio
# 2      Ohio
# 3    Nevada
# 4    Nevada
# 5    Nevada
# Name: state, dtype: object

# %%
frame2.index = frame2.index+1
frame2
# Out:
#    year   state  pop debt
# 2  2000    Ohio  1.5  NaN
# 3  2001    Ohio  1.7  NaN
# 4  2002    Ohio  3.6  NaN
# 5  2001  Nevada  2.4  NaN
# 6  2002  Nevada  2.9  NaN
# 7  2003  Nevada  3.2  NaN

# %%
frame2.loc[3]
# Out:
# year     2001
# state    Ohio
# pop       1.7
# debt      NaN
# Name: 3, dtype: object

# %%
frame2.iloc[3]
# Out:
# year       2001
# state    Nevada
# pop         2.4
# debt        NaN
# Name: 5, dtype: object

# %%
frame2['debt'] = 16

# %%
frame2
# Out:
#    year   state  pop  debt
# 2  2000    Ohio  1.5    16
# 3  2001    Ohio  1.7    16
# 4  2002    Ohio  3.6    16
# 5  2001  Nevada  2.4    16
# 6  2002  Nevada  2.9    16
# 7  2003  Nevada  3.2    16

# %%
frame2['debt'] = np.arange(6)

# %%
frame2
# Out:
#    year   state  pop  debt
# 2  2000    Ohio  1.5     0
# 3  2001    Ohio  1.7     1
# 4  2002    Ohio  3.6     2
# 5  2001  Nevada  2.4     3
# 6  2002  Nevada  2.9     4
# 7  2003  Nevada  3.2     5

# %%
pd.Series([-1.2, -1.5, -1.7], index=[2, 4, 5])
# Out:
# 2   -1.2
# 4   -1.5
# 5   -1.7
# dtype: float64

# %%
frame2['debt'] = pd.Series([-1.2, -1.5, -1.7], index=[2, 4, 5])

# %%
frame2
# Out:
#    year   state  pop  debt
# 2  2000    Ohio  1.5  -1.2
# 3  2001    Ohio  1.7   NaN
# 4  2002    Ohio  3.6  -1.5
# 5  2001  Nevada  2.4  -1.7
# 6  2002  Nevada  2.9   NaN
# 7  2003  Nevada  3.2   NaN

# %%
frame2["eastern"] = frame2["state"] == "Ohio"

# %%
frame2
# Out:
#    year   state  pop  debt  eastern
# 2  2000    Ohio  1.5  -1.2     True
# 3  2001    Ohio  1.7   NaN     True
# 4  2002    Ohio  3.6  -1.5     True
# 5  2001  Nevada  2.4  -1.7    False
# 6  2002  Nevada  2.9   NaN    False
# 7  2003  Nevada  3.2   NaN    False

# %%
# New columns cannot be created with the frame2.eastern dot attribute notation

# %%
del frame2["eastern"]

# %%
frame2.columns
# Out:
# Index(['year', 'state', 'pop', 'debt'], dtype='object')

# %%
# The column returned from indexing a DataFrame is a view on the underlying data, not a copy. Thus, any in-place modifications to the Series will be reflected in the DataFrame.
# The column can be explicitly copied with the Series’s copy method.

# %%
# If the nested dictionary is passed to the DataFrame, pandas will interpret the outer dictionary keys as the columns, and the inner keys as the row indices:

# %%
populations = {"Ohio": {2000: 1.5, 2001: 1.7, 2002: 3.6}, "Nevada": {2001: 2.4, 2002: 2.9}}
populations_df = pd.DataFrame(populations)

# %%
populations_df
# Out:
#       Ohio  Nevada
# 2000   1.5     NaN
# 2001   1.7     2.4
# 2002   3.6     2.9

# %%
populations_df.T
# Out:
#         2000  2001  2002
# Ohio     1.5   1.7   3.6
# Nevada   NaN   2.4   2.9

# %%
# Note that transposing discards the column data types if the columns do not all have the same data type, so transposing and then transposing back may lose the previous type information.
# The columns become arrays of pure Python objects in this case.

# %%
frame2.index.name = "year"
frame2.columns.name = "state"

# %%
frame2
# Out:
# state  year   state  pop  debt
# year
# 2      2000    Ohio  1.5  -1.2
# 3      2001    Ohio  1.7   NaN
# 4      2002    Ohio  3.6  -1.5
# 5      2001  Nevada  2.4  -1.7
# 6      2002  Nevada  2.9   NaN
# 7      2003  Nevada  3.2   NaN

# %%
frame2.to_numpy()
# Out:
# array([[2000, 'Ohio', 1.5, -1.2],
#        [2001, 'Ohio', 1.7, nan],
#        [2002, 'Ohio', 3.6, -1.5],
#        [2001, 'Nevada', 2.4, -1.7],
#        [2002, 'Nevada', 2.9, nan],
#        [2003, 'Nevada', 3.2, nan]], dtype=object)

# %%
# Index objects are immutable and thus can’t be modified by the user:

# %%
labels = pd.Index(np.arange(3))

# %%
labels
# Out:
# Index([0, 1, 2], dtype='int64')

# %%
labels[1] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-79-3700710018.py in <cell line: 0>()
# ----> 1 labels[1] = 5
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    5369     @final
#    5370     def __setitem__(self, key, value) -> None:
# -> 5371         raise TypeError("Index does not support mutable operations")
#    5372
#    5373     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
idx = frame2.index

# %%
idx[0] = 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-82-3482378220.py in <cell line: 0>()
# ----> 1 idx[0] = 1
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    5369     @final
#    5370     def __setitem__(self, key, value) -> None:
# -> 5371         raise TypeError("Index does not support mutable operations")
#    5372
#    5373     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
# In addition to being array-like, an Index also behaves like a fixed-size set:
# Unlike Python sets, a pandas Index can contain duplicate labels:
# Selections with duplicate labels will select all occurrences of that label.

# %%
obj = pd.Series([4.5, 7.2, -5.3, 3.6], index=["d", "b", "a", "c"])

# %%
obj2 = obj.reindex(["a", "b", "c", "d", "e"])
obj2
# Out:
# a   -5.3
# b    7.2
# c    3.6
# d    4.5
# e    NaN
# dtype: float64

# %%
obj3 = pd.Series(["blue", "purple", "yellow"], index=[0, 2, 4])
obj3.reindex(np.arange(6), method="ffill")
# Out:
# 0      blue
# 1      blue
# 2    purple
# 3    purple
# 4    yellow
# 5    yellow
# dtype: object

# %%
frame = pd.DataFrame(np.arange(9).reshape((3, 3)),index=["a", "c", "d"], columns=["Ohio", "Texas", "California"])

# %%
frame
# Out:
#    Ohio  Texas  California
# a     0      1           2
# c     3      4           5
# d     6      7           8

# %%
frame.loc[['c', 'a']]
# Out:
#    Ohio  Texas  California
# c     3      4           5
# a     0      1           2

# %%
frame.loc[['c', 'a'], ['Ohio', 'California', 'Texas']]
# Out:
#    Ohio  California  Texas
# c     3           5      4
# a     0           2      1

# %%
# Since loc operator indexes exclusively with labels, there is also an iloc operator that indexes exclusively with integers to work consistently whether or not the index contains integers:
# When using loc, the expression obj.loc[[0, 1, 2]] will fail when the index does not contain integers

# %%
series = pd.Series([1,2,3,4,5], index=['a','b','c','d','e'])

# %%
series
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
# such indexing only allowed in series not in dataframe, in df it will return the columns
series[['a', 'b']]
# Out:
# a    1
# b    2
# dtype: int64

# %%
series[[0, 1]]
# Out:
# /tmp/ipython-input-17-2155121460.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   series[[0, 1]]
# a    1
# b    2
# dtype: int64

# %%
series.loc[['c', 'd']]
# Out:
# c    3
# d    4
# dtype: int64

# %%
# You can also slice with labels, but it works differently from normal Python slicing in that the endpoint is inclusive:ies
series.loc["c":"d"]
# Out:
# c    3
# d    4
# dtype: int64

# %%
# The row selection syntax data[:2] is provided as a convenience. Passing a single element or a list to the [] operator selects columns.

# %%
data = pd.DataFrame(np.arange(16).reshape((4, 4)),
                    index=["Ohio", "Colorado", "Utah", "New York"],
                    columns=["one", "two", "three", "four"])
data
data["two"]
# below will select columns
data[["three", "one"]]
# Out:
#           three  one
# Ohio          2    0
# Colorado      6    4
# Utah         10    8
# New York     14   12

# %%
# this will select row, seems unintuitive since specifiying labels select columns but slicing select rows
data[:2]
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7

# %%
data.iloc[:2]
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7

# %%
data[data["three"] > 5]
# Out:
#           one  two  three  four
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data["three"] > 5
# Out:
# Ohio        False
# Colorado     True
# Utah         True
# New York     True
# Name: three, dtype: bool

# %%
data < 5
# Out:
#             one    two  three   four
# Ohio       True   True   True   True
# Colorado   True  False  False  False
# Utah      False  False  False  False
# New York  False  False  False  False

# %%
data[data < 5] = 0

# %%
data
# Out:
#           one  two  three  four
# Ohio        0    0      0     0
# Colorado    0    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data.loc["Colorado"]
# Out:
# one      0
# two      5
# three    6
# four     7
# Name: Colorado, dtype: int64

# %%
# can select both rows and columns by passing labels with loc and iloc both
data.loc[["Colorado", "Utah"], ["two",	"three"]]
# Out:
#           two  three
# Colorado    5      6
# Utah        9     10

# %%
data
# Out:
#           one  two  three  four
# Ohio        0    0      0     0
# Colorado    0    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data.iloc[[1, 0], [3, 2, 0]]
# Out:
#           four  three  one
# Colorado     7      6    0
# Ohio         0      0    0

# %%
data.three > 5
# Out:
# Ohio        False
# Colorado     True
# Utah         True
# New York     True
# Name: three, dtype: bool

# %%
data.iloc[:, :3]
# Out:
#           one  two  three
# Ohio        0    0      0
# Colorado    0    5      6
# Utah        8    9     10
# New York   12   13     14

# %%
data.iloc[:, :3][data.three > 5]
# Out:
#           one  two  three
# Colorado    0    5      6
# Utah        8    9     10
# New York   12   13     14

# %%
# Boolean arrays can be used with loc but not iloc

# %%
data.loc[data.three >= 2]
# Out:
#           one  two  three  four
# Colorado    0    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
# If you have an axis index containing integers, data selection will always be label oriented.
ser2 = pd.Series(np.arange(3.), index=["a", "b", "c"])
ser2[-1]
# Out:
# /tmp/ipython-input-40-1805194109.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ser2[-1]
# np.float64(2.0)

# %%
ser = pd.Series(np.arange(3.))

# %%
ser.iloc[-1]
# Out:
# np.float64(2.0)

# %%
ser[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     412             try:
# --> 413                 return self._range.index(new_key)
#     414             except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-44-3387420178.py in <cell line: 0>()
# ----> 1 ser[-1]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
#    1123         # Convert generator to list before going through hashable part
#
# ...

# %%
# A good rule of thumb is to avoid chained indexing when doing assignments

# %%
data.loc[data.three == 6]["three"] = 66
# Out:
# /tmp/ipython-input-49-2774952103.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[data.three == 6]["three"] = 66

# %%
data.loc[data.three == 6, "three"] = 66

# %%
data
# Out:
#           one  two  three  four
# Ohio        0    0      0     0
# Colorado    0    5     66     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %% [markdown]
# ### Arithmetic and Data Alignment

# %%
# If you want to instead broadcast over the columns, matching on the rows, you have to use one of the arithmetic methods and specify to match over the index. For example:

# %%
frame = pd.DataFrame(np.arange(12.).reshape((4, 3)),
columns=list("bde"), index=["Utah", "Ohio", "Texas", "Oregon"])

# %%
series3 = frame["d"]

# %%
# The axis that you pass is the axis to match on. In this case we mean to match on the DataFrame’s row index (axis="index") and broadcast across the columns.
frame.sub(series3, axis="index")
# Out:
#           b    d    e
# Utah   -1.0  0.0  1.0
# Ohio   -1.0  0.0  1.0
# Texas  -1.0  0.0  1.0
# Oregon -1.0  0.0  1.0

# %% [markdown]
# ## Function Application and Mapping

# %%
# for applying an element-wise function
# dataframe -> applymap
# Series -> map

# %%
def my_format(x):
  return f"{x:.2f}"

# %%
frame.applymap(my_format)
# Out:
# /tmp/ipython-input-56-1462544007.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   frame.applymap(my_format)
#            b      d      e
# Utah    0.00   1.00   2.00
# Ohio    3.00   4.00   5.00
# Texas   6.00   7.00   8.00
# Oregon  9.00  10.00  11.00

# %%
frame["e"].map(my_format)
# Out:
# Utah       2.00
# Ohio       5.00
# Texas      8.00
# Oregon    11.00
# Name: e, dtype: object

# %%
def f2(x):
  return pd.Series([x.min(), x.max()], index=["min", "max"])

# %%
frame.apply(f2)
# Out:
#        b     d     e
# min  0.0   1.0   2.0
# max  9.0  10.0  11.0

# %%
# Any missing values are sorted to the end of the Series by default
# Missing values can be sorted to the start instead by using the na_position option:
